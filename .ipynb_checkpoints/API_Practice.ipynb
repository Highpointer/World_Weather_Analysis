# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the random module.
import random

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_longs = zip(lats, longs)
lat_longs

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
# Import the API key.
from config import weather_api_key
# API key = "62a9fa4988c24547d882ba44808200a6"

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "62a9fa4988c24547d882ba44808200a6"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=62a9fa4988c24547d882ba44808200a6

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Birmingham"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=62a9fa4988c24547d882ba44808200a6&q=Birmingham

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
phoenix = city_weather.status_code
phoenix
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Tucson"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-110.9265,"lat":32.2217},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01d"}],"base":"stations","main":{"temp":98.22,"feels_like":96.66,"temp_min":95.45,"temp_max":101.44,"pressure":1019,"humidity":24},"visibility":10000,"wind":{"speed":5.01,"deg":14,"gust":10},"clouds":{"all":0},"dt":1657388364,"sys":{"type":2,"id":2007774,"country":"US","sunrise":1657369460,"sunset":1657420389},"timezone":-25200,"id":5318313,"name":"Tucson","cod":200}'

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Phoenix"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Phoenix"
city_weather = requests.get(city_url)
city_weather.json()
#print(city_url)
# Out:
# {'coord': {'lon': -112.074, 'lat': 33.4484},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02d'}],
#  'base': 'stations',
#  'main': {'temp': 102.88,
#   'feels_like': 99.5,
#   'temp_min': 99.59,
#   'temp_max': 106.38,
#   'pressure': 1014,
#   'humidity': 16},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 180},
#  'clouds': {'all': 20},
#  'dt': 1657388269,
#  'sys': {'type': 2,
#   'id': 2008537,
#   'country': 'US',
#   'sunrise': 1657369553,
#   'sunset': 1657420847},
#  'timezone': -25200,
#  'id': 5308655,
#  'name': 'Phoenix',
#  'cod': 200}

# %%
city_weather.json()['weather'][0]['description']
# Out:
# 'few clouds'

# %%
# Get the JSON data.
phoenix_data = city_weather.json()

# %%
lat = phoenix_data["coord"]["lat"]
lng = phoenix_data["coord"]["lon"]
max_temp = phoenix_data["main"]["temp_max"]
humidity = phoenix_data["main"]["humidity"]
clouds = phoenix_data["clouds"]["all"]
wind = phoenix_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 33.4484 -112.074 106.38 16 20 6.91

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = phoenix_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-07-09 17:37:49'

# %%
phoenix_data["weather"]
# Out:
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data. 6.2.6
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_longs = zip(lats, longs)
lat_longs

# %%
lat_longs

# %%
# Create a practice set of random latitude and longitude combinations.
lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269, 33.41305, 47.48425, 0, 78.22, 71.3, -54.92]
longs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282, -111.932667, -122.20655, 0, 15.65, -156.7, -67.62]
lat_longs = zip(lats, longs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_longs)

# %%
# Use the print() function to display the latitude and longitude combinations. 6.1.4
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 75.17111536856893 35.13997824181351
# 30.188077771598984 -43.846727049942814
# 58.72566215823258 73.05228059354448
# -87.88890585809588 -102.81498201690844
# -61.791518405573036 -41.75633790678609
# 63.278320086546216 65.77002774839772
# -26.300287479509734 99.58131878242125
# 28.975256997176587 81.64117308451773
# -81.98668649364902 78.05720007143753
# -41.0257088310915 -71.52225630141486
# -40.65765054895793 -156.03232223261915
# 19.06430004269042 106.29554018503393
# 6.530396050571667 -89.25816409791324
# 74.17338651947014 -48.62975993912829
# 43.61759891035146 82.95326686096416
# -72.225801301648 -117.33804899162485
# -23.50884336599843 -164.05550298785786
# -23.990910784683777 178.32584878911302
# 63.55208791832456 66.0711697514339
# 1.2506604479609393 -155.67622801601436
# -56.42502168430626 80.89533868783195
# -43.55845870923906 117.53085585632152
# -32.758992407502134 126.79048225873538
# -23.14260234271356 -73.58815942903937
# -74.29560467894709 158.7360062664834
# ...

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# skalistyy ru
# ribeira grande pt
# tevriz ru
# punta arenas cl
# ushuaia ar
# andra ru
# carnarvon au
# jumla np
# busselton au
# san carlos de bariloche ar
# mataura pf
# vinh vn
# santa cruz cr
# ilulissat gl
# yining cn
# punta arenas cl
# avarua ck
# isangel vu
# andra ru
# faanui pf
# busselton au
# albany au
# esperance au
# antofagasta cl
# bluff nz
# san patricio mx
# togur ru
# saleaula ws
# ponta do sol cv
# ushuaia ar
# vardo no
# ilulissat gl
# barrow us
# cayenne gf
# vardo no
# rikitea pf
# buarcos pt
# plettenberg bay za
# mazara del vallo it
# tokur ru
# acari pe
# fairbanks us
# constitucion mx
# astoria us
# quatre cocos mu
# sorland no
# kodiak us
# cabo san lucas mx
# rikitea pf
# rikitea pf
# rikitea pf
# carnarvon au
# grand river south east mu
# saint george bm
# tasiilaq gl
# poum nc
# bud no
# geraldton au
# peniche pt
# puerto ayora ec
# sao filipe cv
# north bend us
# busselton au
# hualmay pe
# akyab mm
# georgetown sh
# bilibino ru
# cherskiy ru
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
# Loop Through the List of Cities and Build the City URL. 6.2.6
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list. 6.2.6
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 13 | skalistyy
# Processing Record 2 of Set 13 | ribeira grande
# Processing Record 3 of Set 13 | tevriz
# Processing Record 4 of Set 13 | punta arenas
# Processing Record 5 of Set 13 | ushuaia
# Processing Record 6 of Set 13 | andra
# Processing Record 7 of Set 13 | carnarvon
# Processing Record 8 of Set 13 | jumla
# Processing Record 9 of Set 13 | busselton
# Processing Record 10 of Set 13 | san carlos de bariloche
# Processing Record 11 of Set 13 | mataura
# Processing Record 12 of Set 13 | vinh
# Processing Record 13 of Set 13 | santa cruz
# Processing Record 14 of Set 13 | ilulissat
# Processing Record 15 of Set 13 | yining
# Processing Record 16 of Set 13 | avarua
# Processing Record 17 of Set 13 | isangel
# Processing Record 18 of Set 13 | faanui
# Processing Record 19 of Set 13 | albany
# Processing Record 20 of Set 13 | esperance
# Processing Record 21 of Set 13 | antofagasta
# Processing Record 22 of Set 13 | bluff
# ...

# %%
# Loop through all the cities in the list. 6.2.6
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 33 of Set 25 | skalistyy
# City not found. Skipping...
# Processing Record 34 of Set 25 | ribeira grande
# Processing Record 35 of Set 25 | tevriz
# Processing Record 36 of Set 25 | punta arenas
# Processing Record 37 of Set 25 | ushuaia
# Processing Record 38 of Set 25 | andra
# Processing Record 39 of Set 25 | carnarvon
# Processing Record 40 of Set 25 | jumla
# Processing Record 41 of Set 25 | busselton
# Processing Record 42 of Set 25 | san carlos de bariloche
# Processing Record 43 of Set 25 | mataura
# Processing Record 44 of Set 25 | vinh
# Processing Record 45 of Set 25 | santa cruz
# Processing Record 46 of Set 25 | ilulissat
# Processing Record 47 of Set 25 | yining
# Processing Record 48 of Set 25 | avarua
# Processing Record 49 of Set 25 | isangel
# Processing Record 50 of Set 25 | faanui
# Processing Record 51 of Set 25 | albany
# Processing Record 52 of Set 25 | esperance
# Processing Record 53 of Set 25 | antofagasta
# ...

# %%
phoenix_data['weather']
# Out:
# [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]

# %%
phoenix_data['dt']
# Out:
# 1657388269

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22468/2594370469.py in <module>
#       6         set_count += 1
#       7         record_count = 1
# ----> 8         time.sleep(60)
#       9
#      10     # Create endpoint URL with each city.
#
# KeyboardInterrupt:

# %%
# Loop through all the cities in the list. 6.2.6
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 9 | ribeira grande
# Processing Record 3 of Set 9 | tevriz
# Processing Record 4 of Set 9 | punta arenas
# Processing Record 5 of Set 9 | ushuaia
# Processing Record 6 of Set 9 | andra
# Processing Record 7 of Set 9 | carnarvon
# Processing Record 8 of Set 9 | jumla
# Processing Record 9 of Set 9 | busselton
# Processing Record 10 of Set 9 | san carlos de bariloche
# Processing Record 11 of Set 9 | mataura
# Processing Record 12 of Set 9 | vinh
# Processing Record 13 of Set 9 | santa cruz
# Processing Record 14 of Set 9 | ilulissat
# Processing Record 15 of Set 9 | yining
# Processing Record 16 of Set 9 | avarua
# Processing Record 17 of Set 9 | isangel
# Processing Record 18 of Set 9 | faanui
# Processing Record 19 of Set 9 | albany
# Processing Record 20 of Set 9 | esperance
# Processing Record 21 of Set 9 | antofagasta
# Processing Record 22 of Set 9 | bluff
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Ribeira Grande  38.5167  -28.7000     70.20        68          40
# 1                   Tevriz  57.5090   72.4042     63.55        76         100
# 2             Punta Arenas -53.1500  -70.9167     33.91        60          20
# 3                  Ushuaia -54.8000  -68.3000     28.06        93         100
# 4                    Andra  62.5147   65.8878     63.48        75          16
# 5                Carnarvon -24.8667  113.6333     66.27       100          75
# 6                    Jumla  29.2747   82.1838     60.55        91         100
# 7                Busselton -33.6500  115.3333     55.99        59          92
# 8  San Carlos De Bariloche -41.1456  -71.3082     40.75        81         100
# 9                  Mataura -46.1927  168.8643     35.47        91          41
#
#    Wind Speed Country                 Date
# 0       11.50      PT  2022-07-09 19:46:45
# ...

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        582 non-null    object
#  1   Lat         582 non-null    float64
#  2   Lng         582 non-null    float64
#  3   Max Temp    582 non-null    float64
#  4   Humidity    582 non-null    int64
#  5   Cloudiness  582 non-null    int64
#  6   Wind Speed  582 non-null    float64
#  7   Country     582 non-null    object
#  8   Date        582 non-null    object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 41.0+ KB

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df_reordered = city_data_df[new_column_order]

# %%
city_data_df_reordered.head(10)
# Out:
#                       City Country                 Date      Lat       Lng  \
# 0           Ribeira Grande      PT  2022-07-09 19:46:45  38.5167  -28.7000
# 1                   Tevriz      RU  2022-07-09 19:46:45  57.5090   72.4042
# 2             Punta Arenas      CL  2022-07-09 19:44:47 -53.1500  -70.9167
# 3                  Ushuaia      AR  2022-07-09 19:44:45 -54.8000  -68.3000
# 4                    Andra      RU  2022-07-09 19:46:46  62.5147   65.8878
# 5                Carnarvon      AU  2022-07-09 19:46:47 -24.8667  113.6333
# 6                    Jumla      NP  2022-07-09 19:46:47  29.2747   82.1838
# 7                Busselton      AU  2022-07-09 19:46:47 -33.6500  115.3333
# 8  San Carlos De Bariloche      AR  2022-07-09 19:46:48 -41.1456  -71.3082
# 9                  Mataura      NZ  2022-07-09 19:46:48 -46.1927  168.8643
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     70.20        68          40       11.50
# 1     63.55        76         100        4.05
# ...

# %%
# Create the output file (CSV). Need to correct this from 2.6.7
output_data_file = "../weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City")
